# %% [markdown]
# <a href="https://colab.research.google.com/github/TakashiNishii/CursoIA/blob/main/CursoIA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Projeto ABC

# %% [markdown]
# ## Importando módulos

# %%
import pandas as pd

# %%
import numpy as np

# %%
print("Este é um texto qualquer")

# %% [markdown]
# ## Importar Dados

# %%
# Rotina de importação

# %% [markdown]
# ### Tratar Dados
